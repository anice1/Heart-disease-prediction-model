# %% [markdown]
# # Heart Disease Prediction Exercise
# This is a personal exercise to practice and improve my proficiency in DS/ML
#
# ### Steps to take in achieving Exercise
# 1. Get the data ready
# 2. Pick a model to solve the problem
# 3. Split data into training and testing sets (Feature Engineering)
# 4. Fit the model to data and make prediction
# 5. save and reload trained data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1. Get the data ready

# %%
#Import data
heart_disease = pd.read_csv('heart.csv')

heart_disease
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
# Check for missing values
heart_disease.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %% [markdown]
# ## 2. Pick a model

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

# %% [markdown]
# ## 3. Split the data (Feature Engineering)

# %%
X = heart_disease.drop('output', axis=1)
y = heart_disease['output']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# X_test.shape, X_train.shape, y_train.shape, y_test.shape

# %% [markdown]
# ## 4. Fit the model to the data

# %%
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.819672131147541
